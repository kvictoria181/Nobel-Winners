# %% [markdown]
# <a href="https://colab.research.google.com/github/kvictoria181/Nobel-Winners/blob/main/Tiny_Coders_IDA_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path="/content/drive/MyDrive/Dataset/archive (1).zip (Unzipped Files)/nobel_prize_awarded_1901_2019.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#                            Name  Year                Category    Countries  \
# 0                Frédéric Passy  1901                   Peace       France
# 1               Sully Prudhomme  1901              Literature       France
# 2        Emil Adolf von Behring  1901  Physiology or Medicine      Germany
# 3               Wilhelm Röntgen  1901                 Physics      Germany
# 4  Jacobus Henricus van 't Hoff  1901               Chemistry  Netherlands
#
#   Gender Description Details
# 0    Man         NaN     NaN
# 1    Man         NaN     NaN
# 2    Man         NaN     NaN
# 3    Man         NaN     NaN
# 4    Man         NaN     NaN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path1="/content/drive/MyDrive/Dataset/archive (1).zip (Unzipped Files)/nobel_prize_awarded_country_details_1901_2019.csv"
df=pd.read_csv(path1)
df.head(5)
# Out:
#                 Name  Year        Country      Countries   Category Gender  \
# 0    14th Dalai Lama  1989          Tibet          Tibet      Peace    Man
# 1  A. Michael Spence  2001  United States  United States  Economics    Man
# 2          Aage Bohr  1975        Denmark        Denmark    Physics    Man
# 3  Aaron Ciechanover  2004         Israel         Israel  Chemistry    Man
# 4         Aaron Klug  1982      Lithuania      Lithuania  Chemistry    Man
#
#           Details
# 0   born in Tibet
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
path2="/content/drive/MyDrive/Dataset/archive (1).zip (Unzipped Files)/nobel_prize_awarded_women_details_1901_2019.csv"
df=pd.read_csv(path2)
df.head(5)
# Out:
#                  Name  Year        Country                Category  \
# 0          Ada Yonath  2009         Israel               Chemistry
# 1         Alice Munro  2013         Canada              Literature
# 2         Alva Myrdal  1982         Sweden                   Peace
# 3    Aung San Suu Kyi  1991          Burma                   Peace
# 4  Barbara McClintock  1983  United States  Physiology or Medicine
#
#                                          Description Details  \
# 0  "For studies of the structure and function of ...     NaN
# 1           "Master of the contemporary short story"     NaN
# 2       "Former Cabinet Minister; Diplomat; Writer."     NaN
# 3  "For her non-violent struggle for democracy an...     NaN
# 4     "For her discovery of mobile genetic elements"     NaN
#
#                                            Shares
# 0  (shared with Pierre Curie and Henri Becquerel)
# 1                                             NaN
# ...

# %%
path="/content/drive/MyDrive/Dataset/archive (1).zip (Unzipped Files)/nobel_prize_awarded_1901_2019.csv"
df=pd.read_csv(path)
df.drop_duplicates()
df.replace('Russia and Soviet Union', 'Russia')
# Out:
#                              Name  Year                Category  \
# 0                  Frédéric Passy  1901                   Peace
# 1                 Sully Prudhomme  1901              Literature
# 2          Emil Adolf von Behring  1901  Physiology or Medicine
# 3                 Wilhelm Röntgen  1901                 Physics
# 4    Jacobus Henricus van 't Hoff  1901               Chemistry
# ..                            ...   ...                     ...
# 943               Tawakkol Karman  2011                   Peace
# 944                 Toni Morrison  1993              Literature
# 945                     Tu Youyou  2015  Physiology or Medicine
# 946               Wangari Maathai  2004                   Peace
# 947            Wisława Szymborska  1996              Literature
#
#          Countries Gender                                        Description  \
# 0           France    Man                                                NaN
# ...

# %%
df.shape
# Out:
# (948, 7)

# %%
df.isnull()
# Out:
#       Name   Year  Category  Countries  Gender  Description  Details
# 0    False  False     False      False   False         True     True
# 1    False  False     False      False   False         True     True
# 2    False  False     False      False   False         True     True
# 3    False  False     False      False   False         True     True
# 4    False  False     False      False   False         True     True
# ..     ...    ...       ...        ...     ...          ...      ...
# 943  False  False     False      False   False        False     True
# 944  False  False     False      False   False        False     True
# 945  False  False     False      False   False        False     True
# 946  False  False     False      False   False        False     True
# 947  False  False     False      False   False        False     True
#
# [948 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Name             0
# Year             0
# Category         0
# Countries        0
# Gender           0
# Description    894
# Details        933
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1827

# %%
#Filling Null Values

df2 = df.fillna(value = 0)
df2
# Out:
#                              Name  Year                Category  \
# 0                  Frédéric Passy  1901                   Peace
# 1                 Sully Prudhomme  1901              Literature
# 2          Emil Adolf von Behring  1901  Physiology or Medicine
# 3                 Wilhelm Röntgen  1901                 Physics
# 4    Jacobus Henricus van 't Hoff  1901               Chemistry
# ..                            ...   ...                     ...
# 943               Tawakkol Karman  2011                   Peace
# 944                 Toni Morrison  1993              Literature
# 945                     Tu Youyou  2015  Physiology or Medicine
# 946               Wangari Maathai  2004                   Peace
# 947            Wisława Szymborska  1996              Literature
#
#          Countries Gender                                        Description  \
# 0           France    Man                                                  0
# ...

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df3 = df.fillna(value = 5)
df3
# Out:
#                              Name  Year                Category  \
# 0                  Frédéric Passy  1901                   Peace
# 1                 Sully Prudhomme  1901              Literature
# 2          Emil Adolf von Behring  1901  Physiology or Medicine
# 3                 Wilhelm Röntgen  1901                 Physics
# 4    Jacobus Henricus van 't Hoff  1901               Chemistry
# ..                            ...   ...                     ...
# 943               Tawakkol Karman  2011                   Peace
# 944                 Toni Morrison  1993              Literature
# 945                     Tu Youyou  2015  Physiology or Medicine
# 946               Wangari Maathai  2004                   Peace
# 947            Wisława Szymborska  1996              Literature
#
#          Countries Gender                                        Description  \
# 0           France    Man                                                  5
# ...

# %%
df4 = df.fillna(value = '')
df4
# Out:
#                              Name  Year                Category  \
# 0                  Frédéric Passy  1901                   Peace
# 1                 Sully Prudhomme  1901              Literature
# 2          Emil Adolf von Behring  1901  Physiology or Medicine
# 3                 Wilhelm Röntgen  1901                 Physics
# 4    Jacobus Henricus van 't Hoff  1901               Chemistry
# ..                            ...   ...                     ...
# 943               Tawakkol Karman  2011                   Peace
# 944                 Toni Morrison  1993              Literature
# 945                     Tu Youyou  2015  Physiology or Medicine
# 946               Wangari Maathai  2004                   Peace
# 947            Wisława Szymborska  1996              Literature
#
#          Countries Gender                                        Description  \
# 0           France    Man
# 1           France    Man
# 2          Germany    Man
# 3          Germany    Man
# ...

# %%
path1="/content/drive/MyDrive/Dataset/archive (1).zip (Unzipped Files)/nobel_prize_awarded_country_details_1901_2019.csv"
df=pd.read_csv(path1)
df
# Out:
#                    Name  Year                      Country  \
# 0       14th Dalai Lama  1989                        Tibet
# 1     A. Michael Spence  2001                United States
# 2             Aage Bohr  1975                      Denmark
# 3     Aaron Ciechanover  2004                       Israel
# 4            Aaron Klug  1982                    Lithuania
# ...                 ...   ...                          ...
# 1137        Yuan T. Lee  1986  Taiwan (China, Republic of)
# 1138        Yuan T. Lee  1986                United States
# 1139       Yves Chauvin  2005                       France
# 1140     Zhores Alferov  2000                      Belarus
# 1141     Zhores Alferov  2000      Russia and Soviet Union
#
#                                        Countries   Category Gender  \
# 0                                          Tibet      Peace    Man
# 1                                  United States  Economics    Man
# ...

# %%
df1 = df.fillna(value ='')
df1
# Out:
#                    Name  Year                      Country  \
# 0       14th Dalai Lama  1989                        Tibet
# 1     A. Michael Spence  2001                United States
# 2             Aage Bohr  1975                      Denmark
# 3     Aaron Ciechanover  2004                       Israel
# 4            Aaron Klug  1982                    Lithuania
# ...                 ...   ...                          ...
# 1137        Yuan T. Lee  1986  Taiwan (China, Republic of)
# 1138        Yuan T. Lee  1986                United States
# 1139       Yves Chauvin  2005                       France
# 1140     Zhores Alferov  2000                      Belarus
# 1141     Zhores Alferov  2000      Russia and Soviet Union
#
#                                        Countries   Category Gender  \
# 0                                          Tibet      Peace    Man
# 1                                  United States  Economics    Man
# ...

# %%
df2 = df['Details'].str.lower()
df2
# Out:
# 0                                  born in tibet
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#                           ...
# 1137                                         NaN
# 1138                              born in taiwan
# 1139                                         NaN
# 1140                                         NaN
# 1141     born in then soviet union,  now belarus
# Name: Details, Length: 1142, dtype: object

# %%
 df1.columns
# Out:
# Index(['Name', 'Year', 'Country', 'Countries', 'Category', 'Gender',
#        'Details'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=1142, step=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       1142 non-null   object
#  1   Year       1142 non-null   int64
#  2   Country    1142 non-null   object
#  3   Countries  1142 non-null   object
#  4   Category   1142 non-null   object
#  5   Gender     1142 non-null   object
#  6   Details    1142 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df1['Country']
# Out:
# 0                             Tibet
# 1                     United States
# 2                           Denmark
# 3                            Israel
# 4                         Lithuania
#                    ...
# 1137    Taiwan (China, Republic of)
# 1138                  United States
# 1139                         France
# 1140                        Belarus
# 1141        Russia and Soviet Union
# Name: Country, Length: 1142, dtype: object

# %%
Country_df1 = df1['Country']
Country_df1.head()
# Out:
# 0            Tibet
# 1    United States
# 2          Denmark
# 3           Israel
# 4        Lithuania
# Name: Country, dtype: object

# %%
df1['Details']
# Out:
# 0                                  born in Tibet
# 1
# 2
# 3
# 4
#                           ...
# 1137
# 1138                              Born in Taiwan
# 1139
# 1140
# 1141     Born in then Soviet Union,  now Belarus
# Name: Details, Length: 1142, dtype: object

# %%
path1="/content/drive/MyDrive/Dataset/archive (1).zip (Unzipped Files)/nobel_prize_awarded_country_details_1901_2019.csv"
df=pd.read_csv(path1)
df.Details = df.Details.str.title()
print(df.Details)
# Out:
# 0                                  Born In Tibet
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#                           ...
# 1137                                         NaN
# 1138                              Born In Taiwan
# 1139                                         NaN
# 1140                                         NaN
# 1141     Born In Then Soviet Union,  Now Belarus
# Name: Details, Length: 1142, dtype: object

# %%
df
# Out:
#                    Name  Year                      Country  \
# 0       14th Dalai Lama  1989                        Tibet
# 1     A. Michael Spence  2001                United States
# 2             Aage Bohr  1975                      Denmark
# 3     Aaron Ciechanover  2004                       Israel
# 4            Aaron Klug  1982                    Lithuania
# ...                 ...   ...                          ...
# 1137        Yuan T. Lee  1986  Taiwan (China, Republic of)
# 1138        Yuan T. Lee  1986                United States
# 1139       Yves Chauvin  2005                       France
# 1140     Zhores Alferov  2000                      Belarus
# 1141     Zhores Alferov  2000      Russia and Soviet Union
#
#                                        Countries   Category Gender  \
# 0                                          Tibet      Peace    Man
# 1                                  United States  Economics    Man
# ...

# %%
import pandas as pd

# %%
df2 = df.fillna(value = '')
df2
# Out:
#                    Name  Year                      Country  \
# 0       14th Dalai Lama  1989                        Tibet
# 1     A. Michael Spence  2001                United States
# 2             Aage Bohr  1975                      Denmark
# 3     Aaron Ciechanover  2004                       Israel
# 4            Aaron Klug  1982                    Lithuania
# ...                 ...   ...                          ...
# 1137        Yuan T. Lee  1986  Taiwan (China, Republic of)
# 1138        Yuan T. Lee  1986                United States
# 1139       Yves Chauvin  2005                       France
# 1140     Zhores Alferov  2000                      Belarus
# 1141     Zhores Alferov  2000      Russia and Soviet Union
#
#                                        Countries   Category Gender  \
# 0                                          Tibet      Peace    Man
# 1                                  United States  Economics    Man
# ...

# %%
path2="/content/drive/MyDrive/Dataset/archive (1).zip (Unzipped Files)/nobel_prize_awarded_women_details_1901_2019.csv"
df=pd.read_csv(path2)
df
# Out:
#                            Name  Year                        Country  \
# 0                    Ada Yonath  2009                         Israel
# 1                   Alice Munro  2013                         Canada
# 2                   Alva Myrdal  1982                         Sweden
# 3              Aung San Suu Kyi  1991                          Burma
# 4            Barbara McClintock  1983                  United States
# 5            Bertha von Suttner  1905                 Czech Republic
# 6                Betty Williams  1976        Ireland, United Kingdom
# 7              Carol W. Greider  2009                  United States
# 8   Christiane Nüsslein-Volhard  1995                        Germany
# 9              Donna Strickland  2018                         Canada
# 10                Doris Lessing  2007           Iran, United Kingdom
# 11              Dorothy Hodgkin  1964                 United Kingdom
# 12             Elfriede Jelinek  2004                        Austria
# ...

# %%
df3 = df.fillna(value = '')
df3
# Out:
#                            Name  Year                        Country  \
# 0                    Ada Yonath  2009                         Israel
# 1                   Alice Munro  2013                         Canada
# 2                   Alva Myrdal  1982                         Sweden
# 3              Aung San Suu Kyi  1991                          Burma
# 4            Barbara McClintock  1983                  United States
# 5            Bertha von Suttner  1905                 Czech Republic
# 6                Betty Williams  1976        Ireland, United Kingdom
# 7              Carol W. Greider  2009                  United States
# 8   Christiane Nüsslein-Volhard  1995                        Germany
# 9              Donna Strickland  2018                         Canada
# 10                Doris Lessing  2007           Iran, United Kingdom
# 11              Dorothy Hodgkin  1964                 United Kingdom
# 12             Elfriede Jelinek  2004                        Austria
# ...

# %%
df3.Shares = df3.Shares.str.title()
print(df3.Shares)
# Out:
# 0        (Shared With Pierre Curie And Henri Becquerel)
# 1
# 2
# 3
# 4
# 5
# 6                  (Shared With Nicholas Murray Butler)
# 7                   (Shared With Frédéric Joliot-Curie)
# 8
# 9
# 10                      (Shared With John Raleigh Mott)
# 11    (Shared With Carl Ferdinand Cori And Bernardo ...
# 12    (Shared With J. Hans D. Jensen And Eugene Wigner)
# 13
# 14                           (Shared With Samuel Agnon)
# 15
# 16
# 17     (Shared With Roger Guillemin And Andrew Schally)
# 18
# 19                  (Shared With Alfonso García Robles)
# 20
# 21                          (Shared With Stanley Cohen)
# 22    (Shared With James W. Black And George H. Hitc...
# 23
# 24
# 25
# 26
# 27    (Shared With Edward B. Lewis And Eric F. Wiesc...
# 28
# 29    (Shared With The International Campaign To Ban...
# 30
# 31
# 32
# 33                           (Shared With Richard Axel)
# 34
# 35    (Shared With Harald Zur Hausen And Luc Montagn...
# ...

# %%
df3.sort_values(by='Year', ascending = False, inplace = True)
df3
# Out:
#                            Name  Year                        Country  \
# 17                 Esther Duflo  2019          France, United States
# 9              Donna Strickland  2018                         Canada
# 37                  Nadia Murad  2018                           Iraq
# 18            Frances H. Arnold  2018                  United States
# 40               Olga Tokarczuk  2018                         Poland
# 51                    Tu Youyou  2015                          China
# 48          Svetlana Alexievich  2015               Belarus, Ukraine
# 31             Malala Yousafzai  2014                       Pakistan
# 35              May-Britt Moser  2014                         Norway
# 1                   Alice Munro  2013                         Canada
# 28                Leymah Gbowee  2011                        Liberia
# 49              Tawakkol Karman  2011                          Yemen
# 15        Ellen Johnson Sirleaf  2011                        Liberia
# ...

# %%
df3['Details'] = df3['Details'].str.replace('\d+', '')
df3
# Out:
# <ipython-input-61-442e0ce7279a>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df3['Details'] = df3['Details'].str.replace('\d+', '')
#                            Name  Year                        Country  \
# 17                 Esther Duflo  2019          France, United States
# 9              Donna Strickland  2018                         Canada
# 37                  Nadia Murad  2018                           Iraq
# 18            Frances H. Arnold  2018                  United States
# 40               Olga Tokarczuk  2018                         Poland
# 51                    Tu Youyou  2015                          China
# 48          Svetlana Alexievich  2015               Belarus, Ukraine
# 31             Malala Yousafzai  2014                       Pakistan
# 35              May-Britt Moser  2014                         Norway
# 1                   Alice Munro  2013                         Canada
# ...

# %%
df3 = df3.sort_index(ascending=True)
df3
# Out:
#                            Name  Year                        Country  \
# 0                    Ada Yonath  2009                         Israel
# 1                   Alice Munro  2013                         Canada
# 2                   Alva Myrdal  1982                         Sweden
# 3              Aung San Suu Kyi  1991                          Burma
# 4            Barbara McClintock  1983                  United States
# 5            Bertha von Suttner  1905                 Czech Republic
# 6                Betty Williams  1976        Ireland, United Kingdom
# 7              Carol W. Greider  2009                  United States
# 8   Christiane Nüsslein-Volhard  1995                        Germany
# 9              Donna Strickland  2018                         Canada
# 10                Doris Lessing  2007           Iran, United Kingdom
# 11              Dorothy Hodgkin  1964                 United Kingdom
# 12             Elfriede Jelinek  2004                        Austria
# ...

# %%
path2="/content/drive/MyDrive/Dataset/archive (1).zip (Unzipped Files)/nobel_prize_awarded_women_details_1901_2019.csv"
df3=pd.read_csv(path2)
df3.loc[54] = ['Anne L’Huillier', 2023, 'France, Sweeden', 'Physics', 'For experimental methods that generate attosecond pulses of light for the study of electron dynamics in matter', 'Born in France, worked in Sweden', 'Shared Prize']
df3.loc[55] = ['Emmanuelle Charpentier', 2020, 'France, Germany', 'Chemistry', 'For the development of a method for genome editing', 'Born in France, worked in Germany', 'Shared prize']
df3.loc[56] = ['Andrea Ghez', 2020, 'United States', 'Physics', "For the discovery of a supermassive compact object at the centre of our galaxy", '', 'Shared prize']
df3.loc[57] = ['Carolyn R. Bertozzi', 2022, 'United States', 'Chemistry', 'For the development of click chemistry and bioorthogonal chemistry', '', 'Shared prize']
df3.loc[58] = ['Jennifer A. Doudna', 2020, 'United States', 'Chemistry', 'For the development of a method for genome editing', '', 'Shared prize']
df3.loc[59] = ['Katalin Karikó', 2023, 'Hungary, United States', 'Physiology or Medicine', 'For their discoveries concerning nucleoside base modifications that enabled the development of effective mRNA vaccines against COVID-19', 'Born in Hungary, worked in the United States', 'Shared Prize']
df3.loc[60] = ['Annie Ernaux', 2022, 'France', 'Literature', 'For the courage and clinical acuity with which she uncovers the roots, estrangements and collective restraints of personal memory', '', '']
df3.loc[61] = ['Narges Mohammadi', 2023, 'Iran', 'Peace', 'For her fight against the oppression of women in Iran and her fight to promote human rights and freedom for all', '', '']
df3.loc[62] = ['Maria Ressa', 2021, 'Phillipines', 'Peace', 'For their efforts to safeguard freedom of expression, which is a precondition for democracy and lasting peace', '', 'Shared prize']
df3.loc[63] = ['Claudia Goldin', 2023, 'United States', 'Economics', 'For having advanced our understanding of women’s labour market outcomes', '', '']
df3.loc[64] = ['Louise Glück', 2020, 'United States', 'Literature', 'For her unmistakable poetic voice that with austere beauty makes individual existence universal', '', '']
print = (df3.tail())
df3 = df3.fillna(value = '')
df3.Shares = df3.Shares.str.title()
df3
# Out:
#                   Name  Year        Country                Category  \
# 0           Ada Yonath  2009         Israel               Chemistry
# 1          Alice Munro  2013         Canada              Literature
# 2          Alva Myrdal  1982         Sweden                   Peace
# 3     Aung San Suu Kyi  1991          Burma                   Peace
# 4   Barbara McClintock  1983  United States  Physiology or Medicine
# ..                 ...   ...            ...                     ...
# 60        Annie Ernaux  2022         France              Literature
# 61    Narges Mohammadi  2023           Iran                   Peace
# 62         Maria Ressa  2021    Phillipines                   Peace
# 63      Claudia Goldin  2023  United States               Economics
# 64        Louise Glück  2020  United States              Literature
#
#                                           Description Details  \
# 0   "For studies of the structure and function of ...
# ...

# %%
grouped = df3.groupby(['Year'], as_index=False).count()
plt.bar(grouped['Year'], grouped['Name'])
plt.show()

# %%
grouped = df3.groupby(['Year'], as_index=False).count()
plt.hist(df3['Year'])
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount ('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path=""

# %%
df= pd.read_csv('/content/drive/MyDrive/nobel_prize_awarded_1901_2019.csv')

# %%
df
# Out:
#                              Name  Year                Category  \
# 0                  Frédéric Passy  1901                   Peace
# 1                 Sully Prudhomme  1901              Literature
# 2          Emil Adolf von Behring  1901  Physiology or Medicine
# 3                 Wilhelm Röntgen  1901                 Physics
# 4    Jacobus Henricus van 't Hoff  1901               Chemistry
# ..                            ...   ...                     ...
# 943               Tawakkol Karman  2011                   Peace
# 944                 Toni Morrison  1993              Literature
# 945                     Tu Youyou  2015  Physiology or Medicine
# 946               Wangari Maathai  2004                   Peace
# 947            Wisława Szymborska  1996              Literature
#
#          Countries Gender                                        Description  \
# 0           France    Man                                                NaN
# ...

# %% [markdown]
# Counting Women Vs Men Winners

# %%
import pandas as pd

# %%
pd.value_counts(df['Gender'])
# Out:
# Man             866
# Woman            54
# Organization     28
# Name: Gender, dtype: int64

# %%
from pandas.core.indexes import category
df.mean()
# Out:
# <ipython-input-41-f58cd1d07af9>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Year    1971.118143
# dtype: float64

# %%
df.mode()
# Out:
#                                        Name    Year                Category  \
# 0  International Committee of the Red Cross  2001.0  Physiology or Medicine
# 1                                       NaN     NaN                     NaN
#
#        Countries Gender                                        Description  \
# 0  United States    Man  "For their non-violent struggle for the safety...
# 1            NaN    NaN                                                NaN
#
#                                      Details
# 0  Born in Congress Poland, worked in France
# 1      Born in North Ireland, part of the UK

# %%
df.median()
# Out:
# <ipython-input-65-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Year    1977.0
# dtype: float64

# %%
pd.value_counts(df['Category'])
# Out:
# Physiology or Medicine    219
# Physics                   213
# Chemistry                 184
# Peace                     134
# Literature                116
# Economics                  82
# Name: Category, dtype: int64

# %%
pd.value_counts(df['Countries'])
# Out:
# United States                                   275
# United Kingdom                                   84
# Germany                                          72
# France                                           55
# Sweden                                           28
#                                                ...
# Israel, Poland, Russia and Soviet Union           1
# Belgium, Russia and Soviet Union                  1
# Bosnia and Herzegovina, Croatia, Switzerland      1
# France, Ireland                                   1
# Kenya                                             1
# Name: Countries, Length: 157, dtype: int64

# %%
import pandas as pd

# %%
df
# Out:
#                              Name  Year                Category  \
# 0                  Frédéric Passy  1901                   Peace
# 1                 Sully Prudhomme  1901              Literature
# 2          Emil Adolf von Behring  1901  Physiology or Medicine
# 3                 Wilhelm Röntgen  1901                 Physics
# 4    Jacobus Henricus van 't Hoff  1901               Chemistry
# ..                            ...   ...                     ...
# 943               Tawakkol Karman  2011                   Peace
# 944                 Toni Morrison  1993              Literature
# 945                     Tu Youyou  2015  Physiology or Medicine
# 946               Wangari Maathai  2004                   Peace
# 947            Wisława Szymborska  1996              Literature
#
#          Countries Gender                                        Description  \
# 0           France    Man                                                NaN
# ...

# %%
pd.value_counts(df['Year'])
# Out:
# 2001    15
# 2019    14
# 2013    13
# 1996    13
# 2000    13
#         ..
# 1917     4
# 1924     3
# 1914     3
# 1918     2
# 1916     1
# Name: Year, Length: 116, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Charts

# %%
import matplotlib.pyplot as plt

# %%
# set up figure
plt.figure(figsize=(15,8))
plt.style.use('seaborn-v0_8-pastel')

# get counts of men and women winners by category; using as_index=False allows us to use
# the columns we're grouping by as references in later code
grouped = winners.groupby(['Category', 'Gender'], as_index=False).count()

# make a subplot with 2 rows and 3 columns (one for each category)
# start with chemistry category
chem = grouped[grouped['Category'] == 'Chemistry']
plt.subplot(2, 3, 1)
plt.pie(chem['Name'], labels=chem['Gender'], autopct='%1.1f%%')
plt.title('Chemistry Winners by Gender')

# economics categor
chem = grouped[grouped['Category'] == 'Economics']
plt.subplot(2, 3, 2)
plt.pie(chem['Name'], labels=chem['Gender'], autopct='%1.1f%%')
plt.title('Economics Winners by Gender')

# physiology or medicine category
chem = grouped[grouped['Category'] == 'Physiology or Medicine']
plt.subplot(2, 3, 3)
plt.pie(chem['Name'], labels=chem['Gender'], autopct='%1.1f%%')
plt.title('Physiology or Medicine Winners by Gender')

# physics category
chem = grouped[grouped['Category'] == 'Physics']
plt.subplot(2, 3, 4)
plt.pie(chem['Name'], labels=chem['Gender'], autopct='%1.1f%%')
plt.title('Physics Winners by Gender')

# peace category
chem = grouped[grouped['Category'] == 'Peace']
plt.subplot(2, 3, 5)
plt.pie(chem['Name'], labels=chem['Gender'], autopct='%1.1f%%')
plt.title('Peace Winners by Gender')

# literature category
chem = grouped[grouped['Category'] == 'Literature']
plt.subplot(2, 3, 6)
plt.pie(chem['Name'], labels=chem['Gender'], autopct='%1.1f%%')
plt.title('Literature Winners by Gender')
plt.show()

# %% [markdown]
# # New Section

# %% [markdown]
# Which country is most represented? Top ten nationalities?
# Age of winners? Age in different categories?
# Repeat winners? (maybe)

# %%
 (from statistics import mean)
 statistics.mean(age)
# Out:
#   File "<ipython-input-4-4cb38822ff44>", line 1
#     (from statistics import mean)
#      ^
# SyntaxError: invalid syntax
